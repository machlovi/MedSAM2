# %%
import os
num_cpus = os.cpu_count()
num_workers = max(1, num_cpus // 2)
num_workers
# Out:
# 24

# %%
#Make sure to install tensor baord here (in your jupyter notebook)
# !pip install tensorboard

# %%
# !which tensorboard
#~/.local/bin/tensorboard  <return something like this
# Out:
# ~/.conda/envs/sam3/bin/tensorboard

# %%
#adjust the path for tensor board
import os
os.environ["PATH"] += ":/gpfs/home/machlm03/.local/bin"

# %%
# !kill 96383
# Out:
# /bin/bash: line 0: kill: (96383) - No such process

# %%
# Now run the tensorbaord here
# %reload_ext tensorboard

# %tensorboard --logdir /gpfs/home/machlm03/Segmentation/sam3/traning_logs/tensorboard --port 8008
# Out:
#       <iframe id="tensorboard-frame-e577bf8c85453b35" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e577bf8c85453b35");
#           const url = new URL("/", window.location);
#           const port = 8008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
## Since you are connected with VPN, you need to do port forrwadrding 
## Open a local terminal in your pc/mac and run this

ssh -N -L 8008:localhost:8008 -J machlm03@bigpurple.nyumc.org machlm03@a100-4011.ib.cluster
# Out:
#   Cell In[7], line 4
#     ssh -N -L 8008:localhost:8008 -J machlm03@bigpurple.nyumc.org machlm03@a100-4002.ib.cluster
#                                                                                     ^
# SyntaxError: invalid decimal literal

# %%
### now open the local host:7007 in local brower
